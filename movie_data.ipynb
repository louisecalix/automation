# %%
import pandas as pd

pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)    
df = pd.read_csv('movie_data.csv')
df
# Out:
#                    Title  Year    Genre  TMDB Rating  RT Rating  \
# 0        It Ends with Us  2024  Romance        6.920         58
# 1          Crescent City  2024  Mystery        6.117         17
# 2          Crescent City  2024  Mystery        6.117         17
# 3          Crescent City  2024  Mystery        6.117         17
# 4          Crescent City  2024  Mystery        6.117         17
# 5          Crescent City  2024  Mystery        6.117         17
# 6          Crescent City  2024  Mystery        6.117         17
# 7   Deadpool & Wolverine  2024   Sci-Fi        7.800         78
# 8               Twisters  2024    Drama        7.014         74
# 9               Twisters  2024    Drama        7.014         74
# 10              Twisters  2024    Drama        7.014         74
# 11              Twisters  2024    Drama        7.014         74
# 12              Twisters  2024    Drama        7.014         74
# 13              Twisters  2024    Drama        7.014         74
# 14  Deadpool & Wolverine  2024   Comedy        7.800         78
#
#     Average Rating                Platform  \
# 0               63  No platforms available
# 1               39      Google Play Movies
# 2               39            Amazon Video
# 3               39                Apple TV
# 4               39                 YouTube
# 5               39        Fandango At Home
# 6               39         Microsoft Store
# 7               78  No platforms available
# 8               72      Google Play Movies
# 9               72            Amazon Video
# 10              72                Apple TV
# 11              72                 YouTube
# 12              72        Fandango At Home
# 13              72         Microsoft Store
# 14              78  No platforms available
#
#                                                   URL
# 0                                                 NaN
# 1   https://www.filmaffinity.com/us/jwredirect.php...
# 2   https://www.filmaffinity.com/us/jwredirect.php...
# 3   https://www.filmaffinity.com/us/jwredirect.php...
# 4   https://www.filmaffinity.com/us/jwredirect.php...
# 5   https://www.filmaffinity.com/us/jwredirect.php...
# 6   https://www.filmaffinity.com/us/jwredirect.php...
# 7                                                 NaN
# 8   https://www.filmaffinity.com/us/jwredirect.php...
# 9   https://www.filmaffinity.com/us/jwredirect.php...
# 10  https://www.filmaffinity.com/us/jwredirect.php...
# 11  https://www.filmaffinity.com/us/jwredirect.php...
# 12  https://www.filmaffinity.com/us/jwredirect.php...
# 13  https://www.filmaffinity.com/us/jwredirect.php...
# 14                                                NaN

# %%
df['Average Rating']
# Out:
# 0     77
# 1     54
# 2     54
# 3     83
# 4     83
# 5     83
# 6     83
# 7     83
# 8     83
# 9     75
# 10    75
# 11    75
# 12    75
# 13    75
# 14    75
# 15    75
# 16    39
# 17    39
# 18    39
# 19    39
# 20    39
# 21    39
# 22    63
# 23    78
# Name: Average Rating, dtype: int64
